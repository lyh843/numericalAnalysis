# %% [markdown]
# # Loss Ablation Summary
#
# This notebook reads the `evaluation.txt` files in the current loss ablation directory and provides:
#
# 1. A summary table of `PSNR / MSE / MAE`.
# 2. Image overviews for `comparison.png`, `loss_curve.png`, `metric_curves.png`, and `final_reconstruction.png`.

# %%
from pathlib import Path
import math
import re

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

try:
    import pandas as pd
except ImportError:
    pd = None

BASE_DIR = Path.cwd()
EXPERIMENTS = [
    ('loss_l1', 'L1'),
    ('loss_charbonnier', 'Charbonnier'),
    ('loss_mse_l1', 'MSE + L1'),
    ('loss_mse_edge', 'MSE + Edge'),
]
IMAGE_NAMES = [
    'comparison.png',
    'loss_curve.png',
    'metric_curves.png',
    'final_reconstruction.png',
]

plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['axes.unicode_minus'] = False

# %%
def parse_evaluation_txt(path: Path):
    text = path.read_text(encoding='utf-8')

    def extract(metric: str) -> float:
        match = re.search(rf'{metric}:\s*([0-9.]+)', text)
        if match is None:
            raise ValueError(f'Cannot find {metric} in {path}')
        return float(match.group(1))

    return {
        'PSNR': extract('psnr'),
        'MSE': extract('mse'),
        'MAE': extract('mae'),
    }


records = []
for folder_name, display_name in EXPERIMENTS:
    eval_path = BASE_DIR / folder_name / 'evaluation.txt'
    if eval_path.exists():
        metrics = parse_evaluation_txt(eval_path)
        metrics['Loss'] = display_name
        records.append(metrics)
    else:
        print(f'Missing evaluation file: {eval_path}')

records
# Out:
# [{'PSNR': 29.7488, 'MSE': 0.00105956, 'MAE': 0.01960821, 'Loss': 'L1'},
#  {'PSNR': 30.553, 'MSE': 0.00088044, 'MAE': 0.01844228, 'Loss': 'Charbonnier'},
#  {'PSNR': 30.2017, 'MSE': 0.00095462, 'MAE': 0.01942236, 'Loss': 'MSE + L1'},
#  {'PSNR': 30.7402, 'MSE': 0.0008433, 'MAE': 0.01955922, 'Loss': 'MSE + Edge'}]

# %%
if pd is not None:
    summary_df = pd.DataFrame(records)[['Loss', 'PSNR', 'MSE', 'MAE']]
    display(summary_df.style.format({'PSNR': '{:.4f}', 'MSE': '{:.8f}', 'MAE': '{:.8f}'}))
else:
    print('pandas is not installed. Printing raw records instead:')
    for item in records:
        print(item)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dd5ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd5ac_level0_col0" class="col_heading level0 col0" >Loss</th>
#       <th id="T_dd5ac_level0_col1" class="col_heading level0 col1" >PSNR</th>
#       <th id="T_dd5ac_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_dd5ac_level0_col3" class="col_heading level0 col3" >MAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd5ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd5ac_row0_col0" class="data row0 col0" >L1</td>
#       <td id="T_dd5ac_row0_col1" class="data row0 col1" >29.7488</td>
#       <td id="T_dd5ac_row0_col2" class="data row0 col2" >0.00105956</td>
#       <td id="T_dd5ac_row0_col3" class="data row0 col3" >0.01960821</td>
#     </tr>
#     <tr>
#       <th id="T_dd5ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd5ac_row1_col0" class="data row1 col0" >Charbonnier</td>
#       <td id="T_dd5ac_row1_col1" class="data row1 col1" >30.5530</td>
#       <td id="T_dd5ac_row1_col2" class="data row1 col2" >0.00088044</td>
#       <td id="T_dd5ac_row1_col3" class="data row1 col3" >0.01844228</td>
#     </tr>
#     <tr>
#       <th id="T_dd5ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd5ac_row2_col0" class="data row2 col0" >MSE + L1</td>
#       <td id="T_dd5ac_row2_col1" class="data row2 col1" >30.2017</td>
#       <td id="T_dd5ac_row2_col2" class="data row2 col2" >0.00095462</td>
#       <td id="T_dd5ac_row2_col3" class="data row2 col3" >0.01942236</td>
#     </tr>
#     <tr>
#       <th id="T_dd5ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd5ac_row3_col0" class="data row3 col0" >MSE + Edge</td>
#       <td id="T_dd5ac_row3_col1" class="data row3 col1" >30.7402</td>
#       <td id="T_dd5ac_row3_col2" class="data row3 col2" >0.00084330</td>
#       <td id="T_dd5ac_row3_col3" class="data row3 col3" >0.01955922</td>
#     </tr>
#   </tbody>
# </table>

# %%
def show_image_collection(image_name: str, experiments=EXPERIMENTS, ncols: int = 2):
    total = len(experiments)
    nrows = math.ceil(total / ncols)
    fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 5 * nrows))
    axes = axes.flatten() if hasattr(axes, 'flatten') else [axes]

    for ax, (folder_name, display_name) in zip(axes, experiments):
        image_path = BASE_DIR / folder_name / image_name
        if image_path.exists():
            image = mpimg.imread(image_path)
            ax.imshow(image)
            ax.set_title(display_name, fontsize=12)
        else:
            ax.text(0.5, 0.5, f'Missing\n{image_name}', ha='center', va='center', fontsize=12)
            ax.set_title(display_name, fontsize=12)
        ax.axis('off')

    for ax in axes[total:]:
        ax.axis('off')

    fig.suptitle(image_name, fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
for image_name in IMAGE_NAMES:
    show_image_collection(image_name)
